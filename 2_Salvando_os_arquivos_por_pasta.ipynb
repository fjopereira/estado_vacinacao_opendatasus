# %% [markdown]
# <a href="https://colab.research.google.com/github/fjopereira/estado_vacinacao_opendatasus/blob/main/2_Salvando_os_arquivos_por_pasta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Criando pastas e salvando os CSVs do site, individualmente por pasta no google drive (NESCESSÁRIO ESTAR UTILIZANDO O GOOGLE COLAB COM A CONTA AUTENTICADA NO GOOGLE DRIVE)

# %%
#cria uma pasta
# !mkdir -p '/content/drive/MyDrive/Colab Notebooks/csv'

# %%
#lista das UFs
ufs =['AC',
          'AL',
          'AM',
          'AP',
          'BA',
          'CE',
          'DF',
          'ES',
          'GO',
          'MA',
          'MG',
          'MS',
          'MT',
          'PA',
          'PB',
          'PE',
          'PI',
          'PR',
          'RJ',
          'RN',
          'RO',
          'RR',
          'RS',
          'SC',
          'SE',
          'SP',
          'TO'
]

# %%
#montando as linhas dos scripts para automatizar 
url = "!wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-{}/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3D{}/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv"
for uf in ufs:
  url_c = url.format(uf, uf)
  print(url_c)
# Out:
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AC/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAC/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AL/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAL/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AM/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAM/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AP/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAP/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# ...

# %%
#basta colar os scripts e executar 
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AC/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAC/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AL/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAL/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AM/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAM/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AP/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAP/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-BA/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DBA/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-CE/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DCE/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-DF/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DDF/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-ES/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DES/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-GO/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DGO/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-MA/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DMA/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-MG/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DMG/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-MS/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DMS/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-MT/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DMT/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-PA/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DPA/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-PB/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DPB/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-PE/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DPE/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-PI/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DPI/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-PR/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DPR/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-RJ/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DRJ/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-RN/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DRN/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-RO/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DRO/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-RR/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DRR/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-RS/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DRS/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-SC/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DSC/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-SE/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DSE/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-SP/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DSP/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# !wget -P'/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-TO/' https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DTO/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# Out:
# --2021-07-07 12:43:59--  https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-07-05/uf%3DAC/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv
# Resolving s3-sa-east-1.amazonaws.com (s3-sa-east-1.amazonaws.com)... 52.95.163.43
# Connecting to s3-sa-east-1.amazonaws.com (s3-sa-east-1.amazonaws.com)|52.95.163.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 210116641 (200M) [text/csv]
# Saving to: ‘/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AC/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv.2’
#
# part-00000-4be03acd 100%[===================>] 200.38M  19.8MB/s    in 11s
#
# 2021-07-07 12:44:11 (18.3 MB/s) - ‘/content/drive/MyDrive/Colab Notebooks/csv/vacina-covid-AC/part-00000-4be03acd-26b6-492d-97b9-1c50eb75a4a0.c000.csv.2’ saved [210116641/210116641]
#
# ...
